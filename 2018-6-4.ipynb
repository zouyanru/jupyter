# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/creditcard.csv')
print(df.shape)
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
fig=plt.figure(figsize=(15,12))
plt.subplot(5,6,1); plt.plot(df.V1);plt.subplot(5,6,2); plt.plot(df.V2);
plt.subplot(5,6,3); plt.plot(df.V3);plt.subplot(5,6,14); plt.plot(df.V14);
plt.subplot(5,6,4); plt.plot(df.V4);plt.subplot(5,6,15); plt.plot(df.V15);
plt.subplot(5,6,5); plt.plot(df.V5);plt.subplot(5,6,16); plt.plot(df.V16);
plt.subplot(5,6,6); plt.plot(df.V6);plt.subplot(5,6,17); plt.plot(df.V17);
plt.subplot(5,6,7); plt.plot(df.V7);plt.subplot(5,6,18); plt.plot(df.V18);
plt.subplot(5,6,8); plt.plot(df.V8);plt.subplot(5,6,19); plt.plot(df.V19);
plt.subplot(5,6,9); plt.plot(df.V9);plt.subplot(5,6,20); plt.plot(df.V20);
plt.subplot(5,6,10); plt.plot(df.V10);plt.subplot(5,6,21); plt.plot(df.V21);
plt.subplot(5,6,11); plt.plot(df.V11);plt.subplot(5,6,22); plt.plot(df.V22);
plt.subplot(5,6,12); plt.plot(df.V12);plt.subplot(5,6,23); plt.plot(df.V23);
plt.subplot(5,6,24); plt.plot(df.V24);plt.subplot(5,6,25); plt.plot(df.V25);
plt.subplot(5,6,26); plt.plot(df.V26);plt.subplot(5,6,27); plt.plot(df.V27);
plt.subplot(5,6,28); plt.plot(df.V28);plt.subplot(5,6,29); plt.plot(df.V29);
plt.show()

# %%
from sklearn.cross_validation import train_test_split
feature_names = df.iloc[:, 1:30].coulumns   #切出前29筆的欄位名稱
target=df.iloc[:1, 30:].columns              #切出是否詐騙的欄位名稱
data_features=df[feature_names]           #切出前29個欄位的資料
data_target=df[target]                    #切出是否詐騙欄位資料
X_train,X_test,y_train,y_test=train_test_split(data_features,data_target,train_size=0.70,test_size=0.30,random_state=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-65eb4c9bad59> in <module>()
#       1 from sklearn.cross_validation import train_test_split
# ----> 2 feature_names = df.iloc[:, 1:30].coulumns   #切出前29筆的欄位名稱
#       3 target=df.iloc[:1, 30:].columns              #切出是否詐騙的欄位名稱
#       4 data_features=df[feature_names]           #切出前29個欄位的資料
#       5 data_target=df[target]                    #切出是否詐騙欄位資料
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'coulumns'

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(X_train, y_train.values.ravel())
pred=model.predict(X_test)
import seabron as sns
sns.set()
class_names=['not_fraud' ,'fraud ']
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,pred)
dataframe=pd.DatFrame(matrix,index=class_names,columns=class_names)
sns.heatmap(dataframe,annot=True,cbar=None,cmap='Blues',fmt='g')
plt.title("Confusion Matrix"),plt.tight_layout()
plt.ylabel("True Class"),plt.xlabel("Predicted Class")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ede4f1183c4b> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model= LogisticRegression()
# ----> 3 model.fit(X_train, y_train.values.ravel())
#       4 pred=model.predict(X_test)
#       5 import seabron as sns
#
# NameError: name 'X_train' is not defined
