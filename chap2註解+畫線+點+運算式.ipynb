# %% [markdown]
# 第二章
# 註解

# %%
#單行註解
'''
多行
註解
'''
a=3
print (a)
# Out:
# 3

# %%
#變數設定
x=1
y=10*x
x=x+y
print(x)
print(y)
# Out:
# 11
# 10

# %%
#平行設定
x , y , z = 3 , 4 , 5
x , y = y , x
print(x)
print(y)
# Out:
# 4
# 3

# %%
#複合設定運算
x,y,z = 3,4,5
x+=1  #x=x+1
y*=2  #y=y*2
z**=3 #z=z**3
print(x,y,z)
# Out:
# 4 8 125

# %%
#海倫公式:面積=√￣s(s-a)(s-b)(s-c)
import math
s=(3+4+5)/2
math.sqrt(s*(s-3)*(s-4)*(s-5))
# Out:
# 6.0

# %%
import math
a,b,c=3,4,5
s= (a+b+c)/2
area = math.sqrt(s *(s-a) * (s-b) * (s-c) )
print(area)
a,b,c = 12,33,25
s=(a+b+c)/2
area = math.sqrt(s *(s-a) * (s-b)*(s-c))
print(area)
# Out:
# 6.0
# 126.8857754044952

# %%
x=254
print(type(x))
id(x)
# Out:
# <class 'int'>
# 1865715072

# %%
x="write"
print(type(x))
# Out:
# <class 'str'>

# %%
print(0o137)  #八進位
print(0b111)  #二進位
print(0xff)  #十六進位
# Out:
# 95
# 7
# 255

# %% [markdown]
# 2018/03/12

# %% [markdown]
# 20180319 第二章PPT2

# %%
#浮點數floot
print(type(12))
print(type(12.0))
print(8.99e-4)
print(23/1.05)
# Out:
# <class 'int'>
# <class 'float'>
# 0.000899
# 21.904761904761905

# %%
#布林涵式Bool
print(type(True))
x,y=10,20
print(x>y)
print(x+10 <=y)
# Out:
# <class 'bool'>
# False
# True

# %%
#複數complex
aComplex=4.23+8.5j
print(aComplex)
print(aComplex.real)
print(aComplex.imag)
print(aComplex.conjugate())
# Out:
# (4.23+8.5j)
# 4.23
# 8.5
# (4.23-8.5j)

# %%
#柱體體積=底面積*高 ; 錐體體積=柱體體積/3
import math
print(4* (math.pi * 4.5 * 4.5 * 4.5)/3)
# Out:
# 381.7035074111598

# %%
#隨機畫出50的點
import numpy as np
import matplotlib.pyplot as pt
N=50
x=np.random.rand(N)
y=np.random.rand(N)
pt.scatter(x,y)
pt.show()

# %%
#畫出sin wave
import numpy as np
import matplotlib.pyplot as pt
x=np.arange(0,360)
y=np.sin(x*np.pi/180.0)
pt.xlim(0,360)
pt.ylim(-1.2,1.2)
pt.title("Sin function")
pt.plot(x,y)
pt.show()

# %%
#畫出sin wave && cos wave
import numpy as np
import matplotlib.pyplot as pt  #畫圖
x=np.arange(0,360)
y=np.sin(x*np.pi/180.0)
z=np.cos(x*np.pi/180.0)
pt.xlim(0,360)
pt.ylim(-1.2,1.2)
pt.title("Sin function")
pt.plot(x,y, color="blue",label="sin wave")
pt.plot(x,z, color="red",label="cos wave")
pt.xlabel("degree")
pt.ylabel("value")
pt.legend()
pt.show()

# %%
import numpy as np
import matplotlib.pyplot as pt
x=[1,2,3,4]
pt.plot(x,"r--") #r-- 紅色虛線
y=[1.5,2.5,3.5] 
pt.plot(y,"gs") #gs 綠色的方塊
pt.show()

# %%
import numpy as np
import matplotlib.pyplot as pt  
x=[1,2,3,4]
y=[5,6,5,6]
pt.plot(x,y)
pt.show()

# %%
import numpy as np
import matplotlib.pyplot as pt
x=[1,2,3,4]
y=[3,7,2,6]
pt.bar(x,y,label="bar chart")
pt.legend()
pt.show()

# %%
#3D圖片
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np
from matplotlib import cm


def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

xgrid = np.linspace(-3, 3, 50)
ygrid = xgrid
x, y = np.meshgrid(xgrid, ygrid)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,
                y,
                f(x, y),
                rstride=2, cstride=2,
                cmap=cm.jet,
                alpha=0.7,
                linewidth=0.25)
ax.set_zlim(-0.5, 1.0)
plt.show()
